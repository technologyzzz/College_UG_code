# %% [markdown]
# # MK Praktikum Unggulan Universitas Gunadarma
# # Mata Kuliah: Praktikum Teknologi Kecerdasan Artifisial (Tingkat 1)

# %% [markdown]
# ---

# %% [markdown]
# # Pertemuan I

# %% [markdown]
# ## Kemampuan CPU vs GPU

# %% [markdown]
# Pemrosesan data antara penggunaan CPU dan GPU sangat berbeda. Di bawah ini adalah contoh program dengan menggunakan python 3 untuk melihat perbandingan kemampuan antara penggunaan CPU dengan GPU.

# %% [markdown]
# <img src="https://graphicscompendium.com/intro/figures/cpu-vs-gpu.svg" width="400">

# %% [markdown]
# ### Program:

# %% [markdown]
# Di bawah ini adalah contoh program python menggunakan library numpy yang memanfaatkan CPU dan juga cupy yang memanfaatkan GPU. Sementara library time digunakan untuk melakukan perhitungan waktu yang diperlukan.

# %%
import numpy as np
import cupy as cp
import time

# %% [markdown]
# Kode di bawah ini membuat array 3D dengan jumlah 1 Miliar, untuk Numpy dan CuPy.

# %%
### Numpy dan CPU
s = time.time()
x_cpu = np.ones((1000,1000,1000))
e = time.time()
print("Waktu yang diperlukan untuk CPU:", e - s)
# Out:
# Waktu yang diperlukan untuk CPU: 3.2124483585357666

# %%
### CuPy dan GPU
s = time.time()
x_gpu = cp.ones((1000,1000,1000))
cp.cuda.Stream.null.synchronize()
e = time.time()
print("Waktu yang diperlukan untuk GPU:", e - s)
# Out:
# Waktu yang diperlukan untuk GPU: 0.7608637809753418

# %% [markdown]
# Dari hasil di atas dapat dilihat perbedaan hasil kecepatan waktu antara penggunaan CPU dan GPU. Program berikutnya untuk melakukan operasi matematika terhadap array yaitu dengan mengkalikannya dengan nilai tertentu.

# %%
### Nilai yang akan dikalikan dengan array
n = 5

# %%
### Numpy dan CPU
s = time.time()
x_cpu *= n
e = time.time()
print("Waktu yang diperlukan untuk CPU:", e - s)
# Out:
# Waktu yang diperlukan untuk CPU: 0.8865945339202881

# %%
### CuPy and GPU
s = time.time()
x_gpu *= n
cp.cuda.Stream.null.synchronize()
e = time.time()
print("Waktu yang diperlukan untuk GPU:", e - s)
# Out:
# Waktu yang diperlukan untuk GPU: 0.17106080055236816

# %% [markdown]
# #Kesimpulan
#
# Data ini menegaskan bahwa GPU jauh lebih efisien untuk komputasi numerik skala besar, terutama pada tugas-tugas yang dapat diparalelkan seperti operasi element-wise pada array yang masif.
#
# Namun, perlu diingat bahwa tidak semua tugas cocok untuk GPU. Overhead transfer data dan sinkronisasi bisa menjadi penghambat jika data kecil atau komputasi tidak paralel.
#
# Menurut saya pemahaman ini penting untuk memilih arsitektur yang tepat sesuai kebutuhan.

# %% [markdown]
# ---
#
#
# Copyright © Pengelola MK Praktikum Unggulan (Praktikum DGX), Universitas Gunadarma
#
#
# https://www.praktikum-hpc.gunadarma.ac.id/
